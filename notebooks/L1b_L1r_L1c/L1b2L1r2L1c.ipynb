# %% [markdown]
# # JB4 CIMR Double Remap L1b-->L1r-->L1c
#
# This notebook describes how to do a double remap for L1b to L1r to L1c. The user is free to play with different algorithms and other parameters. The default for this notebook is a CIMR remap from Ka BAND to L band, followed by a remap to an EASE2 36km grid. We advise the user to follow the steps for this default configuration first, after which they can play with the parameters.
#
# You will need to enter the path to the L1b data in the configuration file, which is also saved in this folder. The output location will also need to be specified in the configuration file.

# %% [markdown]
# # Step 1 - Import relevant modules

# %%
# Import Relevant Modules
from cimr_rgb.config_file import ConfigFile
from cimr_rgb.data_ingestion import DataIngestion
from cimr_rgb.regridder import ReGridder
from cimr_rgb.grid_generator import GRIDS
from cimr_rgb.product_generator import ProductGenerator

import copy
from numpy import full, nan, nanmean, isnan, isinf, polyfit

# You will need to configure matplotlib for your machine, you can probably remove the two lines below. 
import matplotlib # Remove this is plotting issues. 
tkagg = matplotlib.use('TkAgg') # Remove this if plotting issues. 
import matplotlib.pyplot as plt
plt.ion()

# %% [markdown]
# # Step 2 - Add your paths to the configuration file, load the configuration file and validate the configuration file

# %%
# Define path for configuration file of the first regrid.
config_1_path = '/home/beywood/Desktop/MS3/CIMR-RGB/notebooks/L1b_L1r_L1c/l1bl1rl1c_config.xml'

# Validate your config file
config_object_L1b2L1r = ConfigFile(config_1_path)
# Out:
# /home/beywood/ST/CIMR_RGB/CIMR-RGB/dpr/L1B/CIMR/SCEPS_l1b_sceps_geo_central_america_scene_1_unfiltered_tot_minimal_nom_nedt_apc_tot_v2p1.nc

# %%
# You can inspect the parameters in the config file. There are additional parameters relevant to your particular configuration
# that are added as part of the validation. 
for attr, value in config_object_L1b2L1r.__dict__.items():
    print(f"{attr}: {value}")
# Out:
# output_path: /home/beywood/Desktop/MS3/CIMR-RGB/notebooks/L1b_L1r_L1c
# timestamp: 2024-12-10_12-55-58
# timestamp_fmt: %Y-%m-%d_%H-%M-%S
# logpar_config: {'version': 1, 'disable_existing_loggers': False, 'loggers': {'rgb-logger': {'level': 'INFO', 'handlers': ['stdout', 'file'], 'propagate': False}}, 'handlers': {'stdout': {'class': 'logging.StreamHandler', 'formatter': 'simple', 'stream': 'ext://sys.stdout', 'level': 'INFO'}, 'file': {'class': 'logging.FileHandler', 'level': 'INFO', 'formatter': 'balanced', 'filename': PosixPath('/home/beywood/Desktop/MS3/CIMR-RGB/notebooks/L1b_L1r_L1c/logs/l1bl1rl1c_config.log'), 'mode': 'w'}}, 'formatters': {'simple': {'format': '[%(name)s - %(levelname)s]: %(message)s'}, 'simple2': {'format': '[%(name)s - %(levelname)s | %(module)s - L%(lineno)d]: %(message)s'}, 'advanced': {'format': '[%(levelname)s][%(name)s][%(module)s][%(funcName)s][L%(lineno)d][%(asctime)s]: %(message)s', 'datefmt': '%Y-%m-%dT%H:%M:%S%z'}, 'balanced': {'format': '[%(asctime)s][%(levelname)s|%(name)s][%(module)s|%(funcName)s|L%(lineno)d]: %(message)s', 'datefmt': '%Y-%m-%dT%H:%M:%S'}}}
# logger_name: rgb-logger
# logger: <Logger rgb-logger (INFO)>
# logpar_decorate: True
# product_version: 1.0.0
# creator_email: test@email.com
# creator_url: insert your url
# creator_institution: insert your institution
# creator_name: insert your name
# input_data_type: CIMR
# input_data_path: /home/beywood/ST/CIMR_RGB/CIMR-RGB/dpr/L1B/CIMR/SCEPS_l1b_sceps_geo_central_america_scene_1_unfiltered_tot_minimal_nom_nedt_apc_tot_v2p1.nc
# antenna_patterns_path: /home/beywood/ST/CIMR_RGB/CIMR-RGB/dpr/antenna_patterns/CIMR
# quality_control: False
# grid_type: L1R
# target_band: ['L']
# source_band: ['KA']
# grid_definition: None
# projection_definition: None
# regridding_algorithm: IDS
# split_fore_aft: True
# save_to_disk: True
# search_radius: 18000.0
# max_neighbours: 20
# boresight_shift: False
# reduced_grid_inds: None
# variable_key_map: {'longitude': 'lon', 'latitude': 'lat', 'bt_h': 'brightness_temperature_h', 'bt_v': 'brightness_temperature_v', 'bt_3': 'brightness_temperature_t3', 'bt_4': 'brightness_temperature_t4', 'processing_scan_angle': 'scan_angle', 'x_position': 'satellite_position', 'y_position': 'satellite_position', 'z_position': 'satellite_position', 'x_velocity': 'satellite_velocity', 'y_velocity': 'satellite_velocity', 'z_velocity': 'satellite_velocity', 'sub_satellite_lon': 'sub_satellite_lon', 'sub_satellite_lat': 'sub_satellite_lat', 'attitude': 'SatelliteBody2EarthCenteredInertialFrame', 'nedt_h': 'nedt_h', 'nedt_v': 'nedt_v', 'nedt_3': 'nedt_3', 'nedt_4': 'nedt_4', 'regridding_n_samples': 'regridding_n_samples', 'regridding_l1b_orphans': 'regridding_l1b_orphans', 'acq_time_utc': 'utc_time', 'azimuth': 'earth_azimuth', 'oza': 'OZA'}
# aft_angle_min: 180
# aft_angle_max: 360
# num_horns: {'L': 1, 'C': 4, 'X': 4, 'KA': 8, 'KU': 8}
# scan_angle_feed_offsets: {}
# u0: {}
# v0: {}
# scan_geometry: {'L': (74, 691), 'C': (74, 10988), 'X': (74, 11228), 'KA': (74, 83160), 'KU': (74, 61536)}
# nedt: {'L': 0.3, 'C': 0.2, 'X': 0.3, 'KA': 0.4, 'KU': 0.7}
# variables_to_regrid: ['bt_h', 'bt_v', 'bt_3', 'bt_4', 'processing_scan_angle', 'longitude', 'latitude', 'nedt_h', 'nedt_v', 'nedt_3', 'nedt_4', 'regridding_n_samples', 'regridding_l1b_orphans', 'acq_time_utc', 'azimuth', 'oza']

# %% [markdown]
# # Step 3 - Ingest L1b data

# %%
# Ingest your data into the CIMR-RGB data dictionary format. 

l1b_data_dict = DataIngestion(config_object_L1b2L1r).ingest_data()
# Out:
# [rgb-logger - INFO]: `combine_cimr_feeds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Started Execution
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Process-Specific CPU Usage (After): 265.50%
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Memory Usage Change: 1.718750 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `combine_cimr_feeds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Started Execution
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Executed in: 0.33s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU User Time (Change): 0.17s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU System Time: 0.17s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU Total Time: 0.34s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Process-Specific CPU Usage (After): 103.40%
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Memory Usage Change: 152.750000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data` -- Started Execution
# [rgb-logger - INFO]: `clean_data` -- Executed in: 0.23s
# [rgb-logger - INFO]: `clean_data` -- CPU User Time (Change): 0.13s
# [rgb-logger - INFO]: `clean_data` -- CPU System Time: 0.10s
# [rgb-logger - INFO]: `clean_data` -- CPU Total Time: 0.23s
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (After): 102.00%
# [rgb-logger - INFO]: `clean_data` -- Memory Usage Change: 5.632812 MB
# [rgb-logger - INFO]: ---------------------

# %% [markdown]
# # Step 4 - Perform the first regrid and Inspect the result

# %%
# Regrid L1b to L1r

l1r_data_dict = ReGridder(config_object_L1b2L1r).regrid_data(l1b_data_dict)
# Out:
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `KA`
# [rgb-logger - INFO]: `sample_selection`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Started Execution
# [rgb-logger - INFO]: `get_l1c_samples`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - WARNING]: UserWarning: Possible more than 20 neighbours within 18000.0 m for some data points (File: /home/beywood/Desktop/MS3/CIMR-RGB/src/cimr_rgb/regridder.py, Line: 156)
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 0.36s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 0.74s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 0.06s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 0.80s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 223.20%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 25.710938 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 0.34s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 0.73s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 0.04s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 0.77s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 224.70%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 22.773438 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Executed in: 0.71s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU User Time (Change): 1.48s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU System Time: 0.10s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU Total Time: 1.58s
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (After): 222.70%
# [rgb-logger - INFO]: `get_l1c_samples` -- Memory Usage Change: 48.484375 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Executed in: 0.80s
# [rgb-logger - INFO]: `sample_selection` -- CPU User Time (Change): 1.56s
# [rgb-logger - INFO]: `sample_selection` -- CPU System Time: 0.10s
# [rgb-logger - INFO]: `sample_selection` -- CPU Total Time: 1.66s
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (After): 207.30%
# [rgb-logger - INFO]: `sample_selection` -- Memory Usage Change: 85.023438 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `longitude_fore`
# [rgb-logger - INFO]: Regridding: `processing_scan_angle_fore`
# [rgb-logger - INFO]: Regridding: `latitude_fore`
# [rgb-logger - INFO]: Regridding: `acq_time_utc_fore`
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: Regridding: `azimuth_fore`
# [rgb-logger - INFO]: Regridding: `oza_fore`
# [rgb-logger - INFO]: Regridding: `bt_4_fore`
# [rgb-logger - INFO]: Regridding: `bt_3_fore`
# [rgb-logger - INFO]: Regridding: `bt_v_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.12s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.12s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.12s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 99.10%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.156250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `longitude_aft`
# [rgb-logger - INFO]: Regridding: `processing_scan_angle_aft`
# [rgb-logger - INFO]: Regridding: `latitude_aft`
# [rgb-logger - INFO]: Regridding: `acq_time_utc_aft`
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: Regridding: `azimuth_aft`
# [rgb-logger - INFO]: Regridding: `oza_aft`
# [rgb-logger - INFO]: Regridding: `bt_4_aft`
# [rgb-logger - INFO]: Regridding: `bt_3_aft`
# [rgb-logger - INFO]: Regridding: `bt_v_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.13s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.12s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.12s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 95.60%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `KA`
# [rgb-logger - INFO]: `reshape_output_l1r_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- Started Execution
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- Executed in: 0.31s
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- CPU User Time (Change): 0.32s
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- CPU Total Time: 0.32s
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- Process-Specific CPU Usage (After): 102.20%
# [rgb-logger - INFO]: `reshape_output_l1r_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------

# %%
# Inspect variables

source_band_data = l1b_data_dict[config_object_L1b2L1r.source_band[0]]
target_band_data = l1b_data_dict[config_object_L1b2L1r.target_band[0]]

 
for variable in source_band_data.keys():
    print(f"{variable}, shape = {source_band_data[variable].shape}")
# Out:
# longitude_fore, shape = (3077216,)
# longitude_aft, shape = (3076624,)
# processing_scan_angle_fore, shape = (3077216,)
# processing_scan_angle_aft, shape = (3076624,)
# latitude_fore, shape = (3077216,)
# latitude_aft, shape = (3076624,)
# nedt_4_fore, shape = (3077216,)
# nedt_4_aft, shape = (3076624,)
# acq_time_utc_fore, shape = (3077216,)
# acq_time_utc_aft, shape = (3076624,)
# nedt_v_fore, shape = (3077216,)
# nedt_v_aft, shape = (3076624,)
# bt_h_fore, shape = (3077216,)
# bt_h_aft, shape = (3076624,)
# azimuth_fore, shape = (3077216,)
# azimuth_aft, shape = (3076624,)
# oza_fore, shape = (3077216,)
# oza_aft, shape = (3076624,)
# bt_4_fore, shape = (3077216,)
# bt_4_aft, shape = (3076624,)
# nedt_3_fore, shape = (3077216,)
# nedt_3_aft, shape = (3076624,)
# bt_3_fore, shape = (3077216,)
# bt_3_aft, shape = (3076624,)
# bt_v_fore, shape = (3077216,)
# bt_v_aft, shape = (3076624,)
# nedt_h_fore, shape = (3077216,)
# nedt_h_aft, shape = (3076624,)
# feed_horn_number_fore, shape = (3077216,)
# feed_horn_number_aft, shape = (3076624,)
# scan_number_fore, shape = (3077216,)
# scan_number_aft, shape = (3076624,)
# sample_number_fore, shape = (3077216,)
# sample_number_aft, shape = (3076624,)

# %%
# Have a look at the L1r output 
fig, axs = plt.subplots(2, 1)
axs[0].imshow(l1r_data_dict['KA']['bt_h_fore'])
axs[0].set_title('bt_h_fore [KA band --> L band]')
axs[0].set_xlabel('Earth Sample Number [-]')
axs[0].set_ylabel('Scan Number [-]')
axs[1].imshow(l1r_data_dict['KA']['bt_h_aft'])
axs[1].set_title('bt_h_aft [KA band --> L band]')
axs[1].set_xlabel('Earth Sample Number [-]')
axs[1].set_ylabel('Scan Number [-]')
# Out:
# Text(0, 0.5, 'Scan Number [-]')

# %% [markdown]
# # Step 5 - Prepare data for the second regrid (L1r-->L1c)

# %%
# Create the configuration for the next regrid
config_object_L1r2L1c = copy.deepcopy(config_object_L1b2L1r)
config_object_L1r2L1c.grid_type = 'L1C'
config_object_L1r2L1c.grid_definition = 'EASE2_G36km'
config_object_L1r2L1c.projection_definition = 'G'

# %%
# Prep your data, using the newly created config object
prepped_l1r_data_dict = DataIngestion(config_object_L1r2L1c).prepare_l1r_for_l1c(l1r_data_dict)
# Out:
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 680.70%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 820.20%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------

# %% [markdown]
# # Step 6 - Perform the second regrid and inspect the result.

# %%
# Perform the second regrid, using the new config object
l1c_data_dict = ReGridder(config_object_L1r2L1c).regrid_data(prepped_l1r_data_dict)
# Out:
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 226.30%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 162.60%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 119.70%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.03s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.03s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.03s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 102.40%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `KA`
# [rgb-logger - INFO]: `sample_selection`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Started Execution
# [rgb-logger - INFO]: `get_l1c_samples`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 0.11s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 0.46s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 0.58s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 1.04s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 960.20%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: -0.046875 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 0.12s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 0.46s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 0.47s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 0.93s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 788.10%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 29.851562 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Executed in: 0.23s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU User Time (Change): 0.93s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU System Time: 1.05s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU Total Time: 1.98s
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (After): 847.60%
# [rgb-logger - INFO]: `get_l1c_samples` -- Memory Usage Change: 29.804688 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Executed in: 0.24s
# [rgb-logger - INFO]: `sample_selection` -- CPU User Time (Change): 0.94s
# [rgb-logger - INFO]: `sample_selection` -- CPU System Time: 1.05s
# [rgb-logger - INFO]: `sample_selection` -- CPU Total Time: 1.99s
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (After): 832.70%
# [rgb-logger - INFO]: `sample_selection` -- Memory Usage Change: 29.804688 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `longitude_fore`
# [rgb-logger - INFO]: Regridding: `processing_scan_angle_fore`
# [rgb-logger - INFO]: Regridding: `latitude_fore`
# [rgb-logger - INFO]: Regridding: `acq_time_utc_fore`
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: Regridding: `azimuth_fore`
# [rgb-logger - INFO]: Regridding: `oza_fore`
# [rgb-logger - INFO]: Regridding: `bt_4_fore`
# [rgb-logger - INFO]: Regridding: `bt_3_fore`
# [rgb-logger - INFO]: Regridding: `bt_v_fore`
# [rgb-logger - INFO]: Regridding: `regridding_n_samples_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 106.80%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `longitude_aft`
# [rgb-logger - INFO]: Regridding: `processing_scan_angle_aft`
# [rgb-logger - INFO]: Regridding: `latitude_aft`
# [rgb-logger - INFO]: Regridding: `acq_time_utc_aft`
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: Regridding: `azimuth_aft`
# [rgb-logger - INFO]: Regridding: `oza_aft`
# [rgb-logger - INFO]: Regridding: `bt_4_aft`
# [rgb-logger - INFO]: Regridding: `bt_3_aft`
# [rgb-logger - INFO]: Regridding: `bt_v_aft`
# [rgb-logger - INFO]: Regridding: `regridding_n_samples_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 103.30%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `KA`

# %%
# Inspect the result by reconstructing the chosen grid from cell_row and cell_col
grid_shape = GRIDS[config_object_L1r2L1c.grid_definition]['n_rows'], GRIDS[config_object_L1r2L1c.grid_definition]['n_cols']

# create nan array with shape of grid_shape
grid_fore, grid_aft = full(grid_shape, nan), full(grid_shape, nan)
variable_fore = l1c_data_dict['KA']['bt_h_fore']
cell_row_fore = l1c_data_dict['KA']['cell_row_fore']
cell_col_fore = l1c_data_dict['KA']['cell_col_fore']
variable_aft = l1c_data_dict['KA']['bt_h_aft']
cell_row_aft = l1c_data_dict['KA']['cell_row_aft']
cell_col_aft = l1c_data_dict['KA']['cell_col_aft']

for i in range(len(cell_row_fore)):
    grid_fore[cell_row_fore[i], cell_col_fore[i]] = variable_fore[i]

for i in range(len(cell_row_aft)):
    grid_aft[cell_row_aft[i], cell_col_aft[i]] = variable_aft[i]

fig, axs = plt.subplots(1, 2)
axs[0].set_title("bt_h_fore [Ka band --> L band --> EASEG36km]")
axs[0].set_xlabel("EASE2_G36km Grid Cols")
axs[0].set_ylabel("EASE2_G36km Grid Rows")
axs[1].set_title("bt_h_aft [Ka band --> L band --> EASEG36km]")
axs[1].set_xlabel("EASE2_G36km Grid Cols")
axs[1].set_ylabel("EASE2_G36km Grid Rows")
axs[0].imshow(grid_fore)
axs[1].imshow(grid_aft)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Step 7 - Generate the L1c product and save to disk

# %%
# Convert to netcdf and save to disk 
ProductGenerator(config_object_L1r2L1c).generate_product(l1c_data_dict)
# Out:
# [rgb-logger - INFO]: Creating group: Measurement
# [rgb-logger - INFO]: Creating group: Navigation
# [rgb-logger - INFO]: Creating group: Processing_flags
# [rgb-logger - INFO]: Creating group: Quality_information

# %% [markdown]
# # Step 8 - Perform a direct regrid (L1b-->L1c) to compare with the double regrid

# %%
# Copy configuration object for a third remap and print the attributes so we can see what we need to change
config_object_L1c_direct = copy.deepcopy(config_object_L1r2L1c)

# Print attributes
for attr, value in config_object_L1c_direct.__dict__.items():
    print(f"{attr}: {value}")
# Out:
# output_path: /home/beywood/Desktop/MS3/CIMR-RGB/notebooks/L1b_L1r_L1c
# timestamp: 2024-12-10_12-55-58
# timestamp_fmt: %Y-%m-%d_%H-%M-%S
# logpar_config: {'version': 1, 'disable_existing_loggers': False, 'loggers': {'rgb-logger': {'level': 'INFO', 'handlers': ['stdout', 'file'], 'propagate': False}}, 'handlers': {'stdout': {'class': 'logging.StreamHandler', 'formatter': 'simple', 'stream': 'ext://sys.stdout', 'level': 'INFO'}, 'file': {'class': 'logging.FileHandler', 'level': 'INFO', 'formatter': 'balanced', 'filename': PosixPath('/home/beywood/Desktop/MS3/CIMR-RGB/notebooks/L1b_L1r_L1c/logs/l1bl1rl1c_config.log'), 'mode': 'w'}}, 'formatters': {'simple': {'format': '[%(name)s - %(levelname)s]: %(message)s'}, 'simple2': {'format': '[%(name)s - %(levelname)s | %(module)s - L%(lineno)d]: %(message)s'}, 'advanced': {'format': '[%(levelname)s][%(name)s][%(module)s][%(funcName)s][L%(lineno)d][%(asctime)s]: %(message)s', 'datefmt': '%Y-%m-%dT%H:%M:%S%z'}, 'balanced': {'format': '[%(asctime)s][%(levelname)s|%(name)s][%(module)s|%(funcName)s|L%(lineno)d]: %(message)s', 'datefmt': '%Y-%m-%dT%H:%M:%S'}}}
# logger_name: rgb-logger
# logger: <Logger rgb-logger (INFO)>
# logpar_decorate: True
# product_version: 1.0.0
# creator_email: test@email.com
# creator_url: insert your url
# creator_institution: insert your institution
# creator_name: insert your name
# input_data_type: CIMR
# input_data_path: /home/beywood/ST/CIMR_RGB/CIMR-RGB/dpr/L1B/CIMR/SCEPS_l1b_sceps_geo_central_america_scene_1_unfiltered_tot_minimal_nom_nedt_apc_tot_v2p1.nc
# antenna_patterns_path: /home/beywood/ST/CIMR_RGB/CIMR-RGB/dpr/antenna_patterns/CIMR
# quality_control: False
# grid_type: L1C
# target_band: ['L']
# source_band: ['KA']
# grid_definition: EASE2_G36km
# projection_definition: G
# regridding_algorithm: IDS
# split_fore_aft: True
# save_to_disk: True
# search_radius: 18000.0
# max_neighbours: 20
# boresight_shift: False
# reduced_grid_inds: None
# variable_key_map: {'longitude': 'lon', 'latitude': 'lat', 'bt_h': 'brightness_temperature_h', 'bt_v': 'brightness_temperature_v', 'bt_3': 'brightness_temperature_t3', 'bt_4': 'brightness_temperature_t4', 'processing_scan_angle': 'scan_angle', 'x_position': 'satellite_position', 'y_position': 'satellite_position', 'z_position': 'satellite_position', 'x_velocity': 'satellite_velocity', 'y_velocity': 'satellite_velocity', 'z_velocity': 'satellite_velocity', 'sub_satellite_lon': 'sub_satellite_lon', 'sub_satellite_lat': 'sub_satellite_lat', 'attitude': 'SatelliteBody2EarthCenteredInertialFrame', 'nedt_h': 'nedt_h', 'nedt_v': 'nedt_v', 'nedt_3': 'nedt_3', 'nedt_4': 'nedt_4', 'regridding_n_samples': 'regridding_n_samples', 'regridding_l1b_orphans': 'regridding_l1b_orphans', 'acq_time_utc': 'utc_time', 'azimuth': 'earth_azimuth', 'oza': 'OZA'}
# aft_angle_min: 180
# aft_angle_max: 360
# num_horns: {'L': 1, 'C': 4, 'X': 4, 'KA': 8, 'KU': 8}
# scan_angle_feed_offsets: {'L': array([-1.31647126]), 'KA': array([-0.        ,  0.60954884, -0.51559233,  0.07659317,  0.67187603,
#        -0.80867305, -0.21233459,  0.38705285])}
# u0: {'L': array([0.69623331]), 'KA': array([0.73561776, 0.73360973, 0.73179026, 0.72980795, 0.7279449 ,
#        0.7257556 , 0.72394301, 0.72208371])}
# v0: {'L': array([0.016]), 'KA': array([ 0.        , -0.0078049 ,  0.0065854 , -0.00097561, -0.0085366 ,
#         0.010244  ,  0.0026829 , -0.004878  ])}
# scan_geometry: {'L': (74, 691), 'C': (74, 10988), 'X': (74, 11228), 'KA': (74, 83160), 'KU': (74, 61536)}
# nedt: {'L': 0.3, 'C': 0.2, 'X': 0.3, 'KA': 0.4, 'KU': 0.7}
# variables_to_regrid: ['bt_h', 'bt_v', 'bt_3', 'bt_4', 'processing_scan_angle', 'longitude', 'latitude', 'nedt_h', 'nedt_v', 'nedt_3', 'nedt_4', 'regridding_n_samples', 'regridding_l1b_orphans', 'acq_time_utc', 'azimuth', 'oza']
# num_target_scans: 74
# num_target_samples: 691

# %%
# Implement required edits to config 
config_object_L1c_direct.target_band = ['KA']

# %%
# We now perform the same regridding steps as before to generate the direct L1b to L1c regrid. 

l1b_data_dict = DataIngestion(config_object_L1c_direct).ingest_data()
l1c_direct_data_dict = ReGridder(config_object_L1c_direct).regrid_data(l1b_data_dict)
# Out:
# [rgb-logger - INFO]: `combine_cimr_feeds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Started Execution
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Executed in: 0.64s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU User Time (Change): 0.17s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU System Time: 0.48s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- CPU Total Time: 0.65s
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Process-Specific CPU Usage (After): 100.90%
# [rgb-logger - INFO]: `combine_cimr_feeds` -- Memory Usage Change: 140.976562 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.37s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.14s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.24s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.38s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 102.40%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 94.144531 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Executed in: 0.40s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU User Time (Change): 0.16s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU System Time: 0.24s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU Total Time: 0.40s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (After): 99.70%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Memory Usage Change: 0.238281 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data` -- Started Execution
# [rgb-logger - INFO]: `clean_data` -- Executed in: 0.14s
# [rgb-logger - INFO]: `clean_data` -- CPU User Time (Change): 0.13s
# [rgb-logger - INFO]: `clean_data` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU Total Time: 0.13s
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (After): 95.80%
# [rgb-logger - INFO]: `clean_data` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 73.40%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 106.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.03s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.04s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.05s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 169.60%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `KA`
# [rgb-logger - INFO]: `sample_selection`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Started Execution
# [rgb-logger - INFO]: `get_l1c_samples`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 0.40s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 0.81s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 0.31s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 1.12s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 283.30%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 34.894531 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 0.42s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 0.80s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 0.36s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 1.16s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 277.20%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 0.214844 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Executed in: 0.82s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU User Time (Change): 1.62s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU System Time: 0.67s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU Total Time: 2.29s
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (After): 278.20%
# [rgb-logger - INFO]: `get_l1c_samples` -- Memory Usage Change: 35.109375 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Executed in: 0.91s
# [rgb-logger - INFO]: `sample_selection` -- CPU User Time (Change): 1.71s
# [rgb-logger - INFO]: `sample_selection` -- CPU System Time: 0.67s
# [rgb-logger - INFO]: `sample_selection` -- CPU Total Time: 2.38s
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (After): 260.30%
# [rgb-logger - INFO]: `sample_selection` -- Memory Usage Change: -35.085938 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `longitude_fore`
# [rgb-logger - INFO]: Regridding: `processing_scan_angle_fore`
# [rgb-logger - INFO]: Regridding: `latitude_fore`
# [rgb-logger - INFO]: Regridding: `acq_time_utc_fore`
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: Regridding: `azimuth_fore`
# [rgb-logger - INFO]: Regridding: `oza_fore`
# [rgb-logger - INFO]: Regridding: `bt_4_fore`
# [rgb-logger - INFO]: Regridding: `bt_3_fore`
# [rgb-logger - INFO]: Regridding: `bt_v_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.03s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.04s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.04s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 132.30%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `longitude_aft`
# [rgb-logger - INFO]: Regridding: `processing_scan_angle_aft`
# [rgb-logger - INFO]: Regridding: `latitude_aft`
# [rgb-logger - INFO]: Regridding: `acq_time_utc_aft`
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: Regridding: `azimuth_aft`
# [rgb-logger - INFO]: Regridding: `oza_aft`
# [rgb-logger - INFO]: Regridding: `bt_4_aft`
# [rgb-logger - INFO]: Regridding: `bt_3_aft`
# [rgb-logger - INFO]: Regridding: `bt_v_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.03s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.03s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.03s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 108.30%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `KA`

# %%
# Create the grid for the double regrid 
grid_double = full(grid_shape, nan)
variable_fore = l1c_data_dict['KA']['bt_h_fore']
cell_row_fore = l1c_data_dict['KA']['cell_row_fore']
cell_col_fore = l1c_data_dict['KA']['cell_col_fore']

for i in range(len(cell_row_fore)):
    grid_double[cell_row_fore[i], cell_col_fore[i]] = variable_fore[i]

# Create the grid for the direct remap
grid_direct = full(grid_shape, nan)
variable_fore = l1c_direct_data_dict['KA']['bt_h_fore']
cell_row_fore = l1c_direct_data_dict['KA']['cell_row_fore']
cell_col_fore = l1c_direct_data_dict['KA']['cell_col_fore']

for i in range(len(cell_row_fore)):
    grid_direct[cell_row_fore[i], cell_col_fore[i]] = variable_fore[i]

    
# Create the map plot comparison
cmap = 'viridis'
# bt_h plt
fig, axs = plt.subplots(1, 3, constrained_layout=True)
im00 = axs[0].imshow(grid_double[70:200, 180:270], cmap=cmap)
axs[0].set_xlabel("EASE2_G36km Grid Cols")
axs[0].set_ylabel("EASE2_G36km Grid Rows")
fig.colorbar(im00, ax=axs[0])
axs[0].set_title('bt_h double remap [Ka --> L --> EASE2]')
im01 = axs[1].imshow(grid_direct[70:200, 180:270], cmap=cmap)
axs[1].set_xlabel("EASE2_G36km Grid Cols")
axs[1].set_ylabel("EASE2_G36km Grid Rows")
fig.colorbar(im01, ax=axs[1])
axs[1].set_title('bt_h direct remap [Ka -> EASE2]')
bt_h_diff = abs(grid_double - grid_direct)
im02 = axs[2].imshow(bt_h_diff[70:200, 180:270], cmap=cmap)
axs[2].set_xlabel("EASE2_G36km Grid Cols")
axs[2].set_ylabel("EASE2_G36km Grid Rows")
fig.colorbar(im02, ax=axs[2])
axs[2].set_title('Difference (bt_h)')

# Create the scatter plot comparison
def scatter_stats(x, y):
    mask = ~isnan(x) & ~isnan(y) & ~isinf(x) & ~isinf(y)
    x = x[mask]
    y = y[mask]
    m, b = polyfit(x, y, 1)
    y_fit = m * x + b

    # Calculate R^2
    ss_res = sum((y - y_fit) ** 2)
    ss_tot = sum((y - y.mean()) ** 2)
    r_squared = 1 - (ss_res / ss_tot)

    return x, y, m, b, y_fit, r_squared

x = grid_double.flatten()
y = grid_direct.flatten()
x_h_fore, y_h_fore, m_h_fore, b_h_fore, y_fit_h_fore, r_squared = scatter_stats(x, y)

fig, axs = plt.subplots()
axs.scatter(x_h_fore, y_h_fore)
axs.plot(x_h_fore, y_fit_h_fore, color='red')
axs.legend(title=f"$R^2 = {r_squared:.3f}$")
axs.set_title('bt_h double regrid vs direct regrid')
axs.set_xlabel('bt_h double [K]')
axs.set_ylabel('bt_h direct[K]')
# Out:
# [rgb-logger - WARNING]: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument. (File: /tmp/ipykernel_550337/3496934524.py, Line: 63)
# Text(0, 0.5, 'bt_h direct[K]')

# %%
# Print Statistics 
# Calculate the average relative difference
fore_mean_diff = nanmean(bt_h_diff)
print(f"Average relative difference for bt_h: {fore_mean_diff} K")
# Calculate percentage Differences
fore_percent_diff = (fore_mean_diff / nanmean(grid_direct)) * 100
print(f"Average percentage difference for bt_h: {fore_percent_diff} %")
# Out:
# Average relative difference for bt_h: 1.3463177777389714 K
# Average percentage difference for bt_h: 0.6630724691935559 %
