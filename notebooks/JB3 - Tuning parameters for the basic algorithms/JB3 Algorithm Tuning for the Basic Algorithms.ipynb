# %% [markdown]
# # JB3 - Algorithm Tuning for the basic algorithms
#
# This notebook will show you how to generate an output for the basic regridding algorithms and play around with the tuneable paramters for these algorithms, which are search_radius and max_neighbours. We will first show a comparison of the 3 different algorithms for the same tuning parameters and then we demonstrate how to play around with the tuning parameters. We will use AMSR2 L1b brightness temperatures regridded to an EASE2 9km grid.
#
# You can edit your config file to do the same process for different radiometers and/or bands/variables.

# %% [markdown]
# # Step 1 - Import relevant modules

# %%
# Import Relevant Modules
from cimr_rgb.config_file import ConfigFile
from cimr_rgb.data_ingestion import DataIngestion
from cimr_rgb.regridder import ReGridder
from cimr_rgb.grid_generator import GRIDS
from cimr_rgb.product_generator import ProductGenerator

import copy
from numpy import full, nan, nanmean, isnan, isinf, polyfit

# You will need to configure matplotlib for your machine, you can probably remove the two lines below. 
import matplotlib # Remove this is plotting issues. 
tkagg = matplotlib.use('TkAgg') # Remove this if plotting issues. 
import matplotlib.pyplot as plt
plt.ion()

# %% [markdown]
# # Step 2 - Add your paths to the configuration file, load the configuration file and validate the configuration file
#
# In this notebook, we show an alternate way to change configuration parameters, by loading 3 separate configuration files. We will use the same inital configuration file, with search radius left empty, but changing the regridding algorithms (NN, IDS, DIB)

# %%
# Define path for configuration file of the first regrid.
config_1_path = '/home/beywood/Desktop/MS3/CIMR-RGB/notebooks/JB3 - Tuning parameters for the basic algorithms/JB3.xml'



# Validate your config file
config_object = ConfigFile(config_1_path)

# You can inspect the parameters in the config file. There are additional parameters relevant to your particular configuration
# that are added as part of the validation. 
for attr, value in config_object.__dict__.items():
    print(f"{attr}: {value}")
# Out:
# /home/beywood/Desktop/MS3/CIMR-RGB/dpr/L1B/SMAP/SMAP_L1B_TB_47185_D_20231201T212120_R18290_001.h5
# output_path: /home/beywood/Desktop/MS3/CIMR-RGB/notebooks/JB3 - Tuning parameters for the basic algorithms
# timestamp: 2024-12-11_21-11-14
# timestamp_fmt: %Y-%m-%d_%H-%M-%S
# logpar_config: {'version': 1, 'disable_existing_loggers': False, 'loggers': {'rgb-logger': {'level': 'INFO', 'handlers': ['stdout', 'file'], 'propagate': False}}, 'handlers': {'stdout': {'class': 'logging.StreamHandler', 'formatter': 'simple', 'stream': 'ext://sys.stdout', 'level': 'INFO'}, 'file': {'class': 'logging.FileHandler', 'level': 'INFO', 'formatter': 'balanced', 'filename': PosixPath('/home/beywood/Desktop/MS3/CIMR-RGB/notebooks/JB3 - Tuning parameters for the basic algorithms/logs/JB3.log'), 'mode': 'w'}}, 'formatters': {'simple': {'format': '[%(name)s - %(levelname)s]: %(message)s'}, 'simple2': {'format': '[%(name)s - %(levelname)s | %(module)s - L%(lineno)d]: %(message)s'}, 'advanced': {'format': '[%(levelname)s][%(name)s][%(module)s][%(funcName)s][L%(lineno)d][%(asctime)s]: %(message)s', 'datefmt': '%Y-%m-%dT%H:%M:%S%z'}, 'balanced': {'format': '[%(asctime)s][%(levelname)s|%(name)s][%(module)s|%(funcName)s|L%(lineno)d]: %(message)s', 'datefmt': '%Y-%m-%dT%H:%M:%S'}}}
# logger_name: rgb-logger
# logger: <Logger rgb-logger (INFO)>
# logpar_decorate: True
# product_version: 1.0.0
# creator_email: test@email.com
# creator_url: insert your url
# creator_institution: insert your institution
# creator_name: insert your name
# input_data_type: SMAP
# input_data_path: /home/beywood/Desktop/MS3/CIMR-RGB/dpr/L1B/SMAP/SMAP_L1B_TB_47185_D_20231201T212120_R18290_001.h5
# antenna_patterns_path: /home/beywood/ST/CIMR_RGB/CIMR-RGB/dpr/antenna_patterns/SMAP/RadiometerAntPattern_170830_v011.h5
# quality_control: True
# grid_type: L1C
# target_band: None
# source_band: []
# grid_definition: EASE2_G36km
# projection_definition: G
# regridding_algorithm: IDS
# split_fore_aft: True
# save_to_disk: True
# search_radius: None
# max_neighbours: 20
# boresight_shift: True
# reduced_grid_inds: None
# aft_angle_min: 90
# aft_angle_max: 270
# scan_geometry: {'L': (779, 241)}
# variable_key_map: {'bt_h': 'tb_h', 'bt_v': 'tb_v', 'bt_3': 'tb_3', 'bt_4': 'tb_4', 'processing_scan_angle': 'antenna_scan_angle', 'longitude': 'tb_lon', 'latitude': 'tb_lat', 'x_position': 'x_pos', 'y_position': 'y_pos', 'z_position': 'z_pos', 'x_velocity': 'x_vel', 'y_velocity': 'y_vel', 'z_velocity': 'z_vel', 'sub_satellite_lon': 'sc_nadir_lon', 'sub_satellite_lat': 'sc_nadir_lat', 'altitude': 'sc_geodetic_alt_ellipsoid', 'faraday_rot_angle': 'faraday_rotation_angle', 'nedt_h': 'nedt_h', 'nedt_v': 'nedt_v', 'nedt_3': 'nedt_3', 'nedt_4': 'nedt_4', 'regridding_n_samples': 'regridding_n_samples', 'regridding_l1b_orphans': 'regridding_l1b_orphans', 'acq_time_utc': 'antenna_scan_time_utc', 'azimuth': 'antenna_earth_azimuth', 'scan_quality_flag': 'antenna_scan_qual_flag', 'data_quality_h': 'tb_qual_flag_h', 'data_quality_v': 'tb_qual_flag_v', 'data_quality_3': 'tb_qual_flag_3', 'data_quality_4': 'tb_qual_flag_4'}
# variables_to_regrid: ['bt_h']

# %% [markdown]
# We will begin the notebook by leaving search radius empty. This enforces the SMAP style neighbour search, in which samples are found that fall only within the output grid cell itself. This take longer than using a cirucular search radius. We begin on a 36km EASE2 Grid.

# %%
# Compare the basic regridding algorithms 

regridding_algos = ['DIB', 'IDS', 'NN']

# Perform 3 separate regrids for the 3 different basic regridding algorithms 

# Ingestion
l1b_data = DataIngestion(config_object).ingest_data()

grid_shape = GRIDS[config_object.grid_definition]['n_rows'], GRIDS[config_object.grid_definition]['n_cols']

output_data = {}
for algo in regridding_algos:

    # Create a new config object for each regrid 
    config = copy.deepcopy(config_object)
    # change the regridding algorithm 
    config.regridding_algorithm = str(algo)
    
    if algo == 'NN':
        # It is required to enforce this on the fly for NN
        config.max_neighbours = 1
        config.search_radius = None
    
    # Perfrom regrid 
    l1c_data = ReGridder(config).regrid_data(l1b_data)
    # Extract data needed for plot comparison
    bt_h = l1c_data['L']['bt_h_fore']
    cell_row = l1c_data['L']['cell_row_fore']
    cell_col = l1c_data['L']['cell_col_fore']
    # Put data on grid 
    grid = full(grid_shape, nan)
    
    for sample in range(len(cell_row)):
        grid[cell_row[sample], cell_col[sample]] = bt_h[sample]

    output_data[algo] = grid
# Out:
# [rgb-logger - INFO]: `read_hdf5`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Started Execution
# [rgb-logger - INFO]: `apply_smap_qc`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `apply_smap_qc` -- Started Execution
# [rgb-logger - INFO]: Applying quality control to: `scan_quality_flag`
# [rgb-logger - INFO]: Applying quality control to: `data_quality_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `bt_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lon`
# [rgb-logger - INFO]: Removing bad quality samples from: `longitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `latitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `processing_scan_angle`
# [rgb-logger - INFO]: Removing bad quality samples from: `altitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lat`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `scan_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `sample_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `feed_horn_number`
# [rgb-logger - INFO]: `apply_smap_qc` -- Executed in: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (After): 186.30%
# [rgb-logger - INFO]: `apply_smap_qc` -- Memory Usage Change: 1.406250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 5.937500 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Executed in: 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (After): 79.90%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Memory Usage Change: -0.914062 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Executed in: 0.10s
# [rgb-logger - INFO]: `read_hdf5` -- CPU User Time (Change): 0.08s
# [rgb-logger - INFO]: `read_hdf5` -- CPU System Time: 0.02s
# [rgb-logger - INFO]: `read_hdf5` -- CPU Total Time: 0.10s
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (After): 104.10%
# [rgb-logger - INFO]: `read_hdf5` -- Memory Usage Change: 33.257812 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data` -- Started Execution
# [rgb-logger - INFO]: `clean_data` -- Executed in: 0.01s
# [rgb-logger - INFO]: `clean_data` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 89.70%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 5.578125 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.03s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.03s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 108.80%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 5.578125 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.04s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.03s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.04s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 96.20%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 5.578125 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection_brute_force`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 206.50%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 759.70%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 135.50%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# /home/beywood/Desktop/MS3/CIMR-RGB/src/cimr_rgb/utils.py:122: RuntimeWarning: invalid value encountered in arccos
#   delta_sigma = arccos(
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 1150.60%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 182.60%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Executed in: 4.70s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU User Time (Change): 4.69s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU System Time: 0.02s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU Total Time: 4.71s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (After): 100.20%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Memory Usage Change: 5.625000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 194.30%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 1.648438 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 1.093750 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.03s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 156.50%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 8.906250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.03s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 129.10%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 8.906250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.04s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.04s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.05s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 128.10%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 8.906250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection_brute_force`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 276.30%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# /home/beywood/Desktop/MS3/CIMR-RGB/src/cimr_rgb/dib.py:21: RuntimeWarning: Mean of empty slice
#   average_values = nanmean(extracted_values, axis=1)
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Executed in: 4.38s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU User Time (Change): 4.38s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU Total Time: 4.39s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (After): 100.20%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Memory Usage Change: 2.500000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 259.60%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.277344 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 5.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 51.40%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 12.031250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.03s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 117.30%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 12.031250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.04s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.03s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.02s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.05s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 122.80%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 17.968750 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection_brute_force`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 476.90%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 85.30%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 2592.90%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 151.90%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 137.30%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Executed in: 4.77s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU User Time (Change): 4.76s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU Total Time: 4.77s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (After): 100.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: bt_h_fore
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: bt_h_aft
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`

# %%
# Plot the data on a 36km grid

fig, axs = plt.subplots(1, 3)
im1 = axs[0].imshow(output_data['NN'][:,700:900], cmap = 'viridis')
axs[0].set_title('NN')
im2 = axs[1].imshow(output_data['DIB'][:,700:900], cmap = 'viridis')
axs[1].set_title('DIB')
im3 = axs[2].imshow(output_data['IDS'][:,700:900], cmap = 'viridis')
axs[2].set_title('IDS')
colorbar = fig.colorbar(im1, ax=axs[0])
colorbar = fig.colorbar(im2, ax=axs[1])
colorbar = fig.colorbar(im3, ax=axs[2])
colorbar.set_label('BT [K]', fontsize=12)
fig.suptitle('EASE2_36km Basic Algorithm Comparison')
plt.show()
# Out:
# {'DIB': array([[238.22451782, 238.46588135, 240.33514404, ..., 238.79963684,
#         238.00788879, 240.15751648],
#        [238.96035767, 238.33963013, 238.76460266, ..., 236.88739014,
#         238.09211731, 239.3848877 ],
#        [232.77294922, 234.99015808, 234.69506836, ..., 230.68786621,
#         231.99543762, 232.25474548],
#        ...,
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan]], shape=(406, 964)), 'IDS': array([[237.19053869, 237.97026355, 238.74528191, ..., 238.47260711,
#         237.03085497, 239.90924429],
#        [237.14267195, 239.4671583 , 239.1956744 , ..., 237.3146695 ,
#         238.11039153, 237.72787137],
#        [234.82498764, 234.8981886 , 235.30529335, ..., 231.15205756,
#         231.50050635, 234.33318644],
#        ...,
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan]], shape=(406, 964)), 'NN': array([[236.70507812, 237.51939392, 236.91722107, ..., 238.2545929 ,
#         236.88757324, 240.38294983],
#        [241.1187439 , 240.00137329, 237.70805359, ..., 236.18592834,
#         238.26101685, 240.690979  ],
#        [235.31794739, 236.28620911, 234.95056152, ..., 233.65635681,
#         236.2915802 , 237.01383972],
#        ...,
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan]], shape=(406, 964))}

# %% [markdown]
# # Moving to a 9km
#
# We now perform the same, but change the grid to a 9km grid to demonstrate the effect of incresaing the search radius.

# %%
# Change the grid to a 9km grid and plt the results 

config_9km = copy.deepcopy(config_object)
config_9km.grid_definition = 'EASE2_G9km'

# Rerun the same code as above with the new grid 

# Ingest data
l1b_data = DataIngestion(config_9km).ingest_data()

# Define grid
grid_shape = GRIDS[config_9km.grid_definition]['n_rows'], GRIDS[config_9km.grid_definition]['n_cols']

output_data = {}
for algo in regridding_algos:
    # Create a new config object for each regrid 
    config = copy.deepcopy(config_9km)
    # change the regridding algorithm 
    config.regridding_algorithm = str(algo)
    if algo == 'NN':
        # It is required to enforce this on the fly for NN
        config.max_neighbours = 1
        config.search_radius = None
    
    # Perfrom regrid 
    l1c_data = ReGridder(config).regrid_data(l1b_data)
    # Extract data needed for plot comparison
    bt_h = l1c_data['L']['bt_h_fore']
    cell_row = l1c_data['L']['cell_row_fore']
    cell_col = l1c_data['L']['cell_col_fore']
    # Put data on grid 
    grid = full(grid_shape, nan)
    
    for sample in range(len(cell_row)):
        grid[cell_row[sample], cell_col[sample]] = bt_h[sample]

    output_data[algo] = grid
# Out:
# [rgb-logger - INFO]: `read_hdf5`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Started Execution
# [rgb-logger - INFO]: `apply_smap_qc`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `apply_smap_qc` -- Started Execution
# [rgb-logger - INFO]: Applying quality control to: `scan_quality_flag`
# [rgb-logger - INFO]: Applying quality control to: `data_quality_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `bt_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lon`
# [rgb-logger - INFO]: Removing bad quality samples from: `longitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `latitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `processing_scan_angle`
# [rgb-logger - INFO]: Removing bad quality samples from: `altitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lat`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `scan_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `sample_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `feed_horn_number`
# [rgb-logger - INFO]: `apply_smap_qc` -- Executed in: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (After): 172.20%
# [rgb-logger - INFO]: `apply_smap_qc` -- Memory Usage Change: 1.406250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 162.30%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 5.625000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Executed in: 0.02s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (After): 112.30%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Memory Usage Change: 5.625000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Executed in: 0.10s
# [rgb-logger - INFO]: `read_hdf5` -- CPU User Time (Change): 0.10s
# [rgb-logger - INFO]: `read_hdf5` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `read_hdf5` -- CPU Total Time: 0.11s
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (After): 109.40%
# [rgb-logger - INFO]: `read_hdf5` -- Memory Usage Change: 23.125000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data` -- Started Execution
# [rgb-logger - INFO]: `clean_data` -- Executed in: 0.01s
# [rgb-logger - INFO]: `clean_data` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 675.30%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 202.90%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.25s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.19s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.07s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 104.60%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 95.554688 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.25s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.19s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.07s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 102.70%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 95.554688 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.31s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.21s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.11s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.32s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 102.70%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 95.882812 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection_brute_force`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 121.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 111.70%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 644.60%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 122.60%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Executed in: 8.82s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU User Time (Change): 8.81s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU Total Time: 8.82s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (After): 100.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 120.20%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.937500 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 126.20%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.24s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.18s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.06s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.24s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 98.70%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 95.640625 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.25s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.19s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.07s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 104.10%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 95.640625 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.30s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.22s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.10s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.32s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 104.90%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 95.753906 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection_brute_force`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 559.20%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 141.40%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 169.60%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 206.80%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 984.40%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 353.90%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Executed in: 9.08s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU User Time (Change): 9.07s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU Total Time: 9.08s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (After): 100.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 92.40%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 7.343750 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 83.20%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 2.812500 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 180.60%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# /home/beywood/Desktop/MS3/CIMR-RGB/src/cimr_rgb/ids.py:33: RuntimeWarning: invalid value encountered in divide
#   output_var = nansum(output_var, axis =1)/ nansum(weights, axis=1)
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.27s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.20s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.07s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.27s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 98.80%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 95.554688 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.28s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.20s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.08s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.28s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 100.40%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 95.554688 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.33s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.22s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.11s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.33s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 99.30%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 95.636719 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection_brute_force`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 167.30%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 928.40%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 202.20%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Executed in: 8.98s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU User Time (Change): 8.94s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU System Time: 0.02s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- CPU Total Time: 8.96s
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Process-Specific CPU Usage (After): 99.80%
# [rgb-logger - INFO]: `sample_selection_brute_force` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: bt_h_fore
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: bt_h_aft
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`

# %%
# Plot the data on a 9km grid

fig, axs = plt.subplots(1, 3)
im1 = axs[0].imshow(output_data['NN'][1075:1125,3140:3220], cmap = 'viridis')
axs[0].set_title('NN')
im2 = axs[1].imshow(output_data['DIB'][1075:1125,3140:3220], cmap = 'viridis')
axs[1].set_title('DIB')
im3 = axs[2].imshow(output_data['IDS'][1075:1125,3140:3220], cmap = 'viridis')
axs[2].set_title('IDS')
colorbar = fig.colorbar(im1, ax=axs[0])
colorbar = fig.colorbar(im2, ax=axs[1])
colorbar = fig.colorbar(im3, ax=axs[2])
colorbar.set_label('BT [K]', fontsize=12)
plt.suptitle('EASE2_G9km')
plt.show()

# %% [markdown]
# Note: In the plot made in the code block above we zoom into the results to demonstrate that there are many empty cells for L band on a 9km EASE grid. The plots appear empty if you display the full gri. In order to fill in the gaps, we can increase the search radius, which is demonstrated in the block below.
#
# We will now show the effect of changing the search radius on a 9km for IDS.

# %%
# Rerun the same code as above with the new grid, using IDS on a 9km grid, for different search radii

search_radius = [5, 10, 30] #km

# Fix the regridding algo 
config_9km.regridding_algorithm = 'IDS'

grid_shape = GRIDS[config_9km.grid_definition]['n_rows'], GRIDS[config_9km.grid_definition]['n_cols']

output_data = {}
for radius in search_radius:
    # Create a new config object for each regrid 
    config = copy.deepcopy(config_9km)
    # change the search radius 
    config.search_radius = float(radius)*1000
    # Ingest Data
    l1b_data = DataIngestion(config_9km).ingest_data()
    
    # Perfrom regrid 
    l1c_data = ReGridder(config).regrid_data(l1b_data)
    # Extract data needed for plot comparison
    bt_h = l1c_data['L']['bt_h_fore']
    cell_row = l1c_data['L']['cell_row_fore']
    cell_col = l1c_data['L']['cell_col_fore']
    # Put data on grid 
    grid = full(grid_shape, nan)
    
    for sample in range(len(cell_row)):
        grid[cell_row[sample], cell_col[sample]] = bt_h[sample]

    output_data[str(radius)] = grid
# Out:
# [rgb-logger - INFO]: `read_hdf5`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Started Execution
# [rgb-logger - INFO]: `apply_smap_qc`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `apply_smap_qc` -- Started Execution
# [rgb-logger - INFO]: Applying quality control to: `scan_quality_flag`
# [rgb-logger - INFO]: Applying quality control to: `data_quality_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `bt_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lon`
# [rgb-logger - INFO]: Removing bad quality samples from: `longitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `latitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `processing_scan_angle`
# [rgb-logger - INFO]: Removing bad quality samples from: `altitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lat`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `scan_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `sample_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `feed_horn_number`
# [rgb-logger - INFO]: `apply_smap_qc` -- Executed in: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (After): 95.30%
# [rgb-logger - INFO]: `apply_smap_qc` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Executed in: 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (After): 93.70%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Executed in: 0.09s
# [rgb-logger - INFO]: `read_hdf5` -- CPU User Time (Change): 0.08s
# [rgb-logger - INFO]: `read_hdf5` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `read_hdf5` -- CPU Total Time: 0.08s
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (After): 91.70%
# [rgb-logger - INFO]: `read_hdf5` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data` -- Started Execution
# [rgb-logger - INFO]: `clean_data` -- Executed in: 0.01s
# [rgb-logger - INFO]: `clean_data` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 155.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.25s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.17s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.07s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.24s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 94.90%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 95.828125 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.19s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.08s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.27s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 104.90%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 95.828125 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.31s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.21s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.11s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.32s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 103.80%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 95.914062 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Started Execution
# [rgb-logger - INFO]: `get_l1c_samples`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 1.52s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 4.00s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 4.02s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 8.02s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 528.80%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 11.539062 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 1.34s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 3.97s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 4.05s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 8.02s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 598.70%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 11.824219 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Executed in: 2.86s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU User Time (Change): 7.97s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU System Time: 8.07s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU Total Time: 16.04s
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (After): 560.10%
# [rgb-logger - INFO]: `get_l1c_samples` -- Memory Usage Change: 23.363281 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Executed in: 2.87s
# [rgb-logger - INFO]: `sample_selection` -- CPU User Time (Change): 7.97s
# [rgb-logger - INFO]: `sample_selection` -- CPU System Time: 8.07s
# [rgb-logger - INFO]: `sample_selection` -- CPU Total Time: 16.04s
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (After): 559.30%
# [rgb-logger - INFO]: `sample_selection` -- Memory Usage Change: 23.363281 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 119.80%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 17.726562 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 77.20%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`
# [rgb-logger - INFO]: `read_hdf5`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Started Execution
# [rgb-logger - INFO]: `apply_smap_qc`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `apply_smap_qc` -- Started Execution
# [rgb-logger - INFO]: Applying quality control to: `scan_quality_flag`
# [rgb-logger - INFO]: Applying quality control to: `data_quality_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `bt_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lon`
# [rgb-logger - INFO]: Removing bad quality samples from: `longitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `latitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `processing_scan_angle`
# [rgb-logger - INFO]: Removing bad quality samples from: `altitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lat`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `scan_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `sample_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `feed_horn_number`
# [rgb-logger - INFO]: `apply_smap_qc` -- Executed in: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (After): 140.40%
# [rgb-logger - INFO]: `apply_smap_qc` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Executed in: 0.02s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU User Time (Change): 0.02s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (After): 130.10%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Executed in: 0.09s
# [rgb-logger - INFO]: `read_hdf5` -- CPU User Time (Change): 0.09s
# [rgb-logger - INFO]: `read_hdf5` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `read_hdf5` -- CPU Total Time: 0.10s
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (After): 109.70%
# [rgb-logger - INFO]: `read_hdf5` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data` -- Started Execution
# [rgb-logger - INFO]: `clean_data` -- Executed in: 0.01s
# [rgb-logger - INFO]: `clean_data` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `clean_data` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (After): 157.80%
# [rgb-logger - INFO]: `clean_data` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.02s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 205.20%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.24s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.18s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.06s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.24s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 99.10%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 95.496094 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.25s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.18s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.06s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.24s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 96.70%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 95.496094 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.32s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.22s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.11s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.33s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 104.70%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 95.597656 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Started Execution
# [rgb-logger - INFO]: `get_l1c_samples`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 1.39s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 3.93s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 4.59s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 8.52s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 613.60%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: -4.453125 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 1.38s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 4.04s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 3.64s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 7.68s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 555.90%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 30.742188 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Executed in: 2.78s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU User Time (Change): 7.97s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU System Time: 8.23s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU Total Time: 16.20s
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (After): 583.10%
# [rgb-logger - INFO]: `get_l1c_samples` -- Memory Usage Change: 26.289062 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Executed in: 2.78s
# [rgb-logger - INFO]: `sample_selection` -- CPU User Time (Change): 7.97s
# [rgb-logger - INFO]: `sample_selection` -- CPU System Time: 8.23s
# [rgb-logger - INFO]: `sample_selection` -- CPU Total Time: 16.20s
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (After): 581.80%
# [rgb-logger - INFO]: `sample_selection` -- Memory Usage Change: 26.289062 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.05s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.04s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.05s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 99.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.218750 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.05s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.03s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.04s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 82.20%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 15.546875 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`
# [rgb-logger - INFO]: `read_hdf5`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Started Execution
# [rgb-logger - INFO]: `apply_smap_qc`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `apply_smap_qc` -- Started Execution
# [rgb-logger - INFO]: Applying quality control to: `scan_quality_flag`
# [rgb-logger - INFO]: Applying quality control to: `data_quality_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `bt_h`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lon`
# [rgb-logger - INFO]: Removing bad quality samples from: `longitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `z_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `latitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `y_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `processing_scan_angle`
# [rgb-logger - INFO]: Removing bad quality samples from: `altitude`
# [rgb-logger - INFO]: Removing bad quality samples from: `sub_satellite_lat`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_velocity`
# [rgb-logger - INFO]: Removing bad quality samples from: `x_position`
# [rgb-logger - INFO]: Removing bad quality samples from: `scan_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `sample_number`
# [rgb-logger - INFO]: Removing bad quality samples from: `feed_horn_number`
# [rgb-logger - INFO]: `apply_smap_qc` -- Executed in: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `apply_smap_qc` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `apply_smap_qc` -- Process-Specific CPU Usage (After): 85.00%
# [rgb-logger - INFO]: `apply_smap_qc` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `GridGenerator` -- Started Execution
# [rgb-logger - INFO]: `GridGenerator` -- Executed in: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `GridGenerator` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Started Execution
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Executed in: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `lonlat_to_xy_cea` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Executed in: 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Process-Specific CPU Usage (After): 88.40%
# [rgb-logger - INFO]: `remove_out_of_bounds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `read_hdf5` -- Executed in: 0.08s
# [rgb-logger - INFO]: `read_hdf5` -- CPU User Time (Change): 0.09s
# [rgb-logger - INFO]: `read_hdf5` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `read_hdf5` -- CPU Total Time: 0.09s
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `read_hdf5` -- Process-Specific CPU Usage (After): 113.40%
# [rgb-logger - INFO]: `read_hdf5` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `clean_data` -- Started Execution
# [rgb-logger - INFO]: `clean_data` -- Executed in: 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `clean_data` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Started Execution
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Executed in: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy_ease2` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `generate_grid_xy` -- Executed in: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU User Time (Change): 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `generate_grid_xy` -- CPU Total Time: 0.01s
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `generate_grid_xy` -- Process-Specific CPU Usage (After): 121.40%
# [rgb-logger - INFO]: `generate_grid_xy` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Started Execution
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Executed in: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU User Time (Change): 0.20s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU System Time: 0.06s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- CPU Total Time: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Process-Specific CPU Usage (After): 101.10%
# [rgb-logger - INFO]: `xy_to_lonlat_cea` -- Memory Usage Change: 95.644531 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `xy_to_lonlat` -- Executed in: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU User Time (Change): 0.20s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU System Time: 0.06s
# [rgb-logger - INFO]: `xy_to_lonlat` -- CPU Total Time: 0.26s
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Process-Specific CPU Usage (After): 98.80%
# [rgb-logger - INFO]: `xy_to_lonlat` -- Memory Usage Change: 95.644531 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_grid` -- Executed in: 0.32s
# [rgb-logger - INFO]: `get_grid` -- CPU User Time (Change): 0.23s
# [rgb-logger - INFO]: `get_grid` -- CPU System Time: 0.10s
# [rgb-logger - INFO]: `get_grid` -- CPU Total Time: 0.33s
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_grid` -- Process-Specific CPU Usage (After): 104.20%
# [rgb-logger - INFO]: `get_grid` -- Memory Usage Change: 95.644531 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Regridding band: `L`
# [rgb-logger - INFO]: `sample_selection`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Started Execution
# [rgb-logger - INFO]: `get_l1c_samples`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - WARNING]: UserWarning: Possible more than 20 neighbours within 30000.0 m for some data points (File: /home/beywood/Desktop/MS3/CIMR-RGB/src/cimr_rgb/regridder.py, Line: 156)
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 1.39s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 4.43s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 3.49s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 7.92s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 570.80%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 54.726562 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_neighbours` -- Started Execution
# [rgb-logger - INFO]: `get_neighbours` -- Executed in: 1.43s
# [rgb-logger - INFO]: `get_neighbours` -- CPU User Time (Change): 5.17s
# [rgb-logger - INFO]: `get_neighbours` -- CPU System Time: 2.86s
# [rgb-logger - INFO]: `get_neighbours` -- CPU Total Time: 8.03s
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_neighbours` -- Process-Specific CPU Usage (After): 559.70%
# [rgb-logger - INFO]: `get_neighbours` -- Memory Usage Change: 40.429688 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_l1c_samples` -- Executed in: 2.83s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU User Time (Change): 9.60s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU System Time: 6.35s
# [rgb-logger - INFO]: `get_l1c_samples` -- CPU Total Time: 15.95s
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_l1c_samples` -- Process-Specific CPU Usage (After): 563.40%
# [rgb-logger - INFO]: `get_l1c_samples` -- Memory Usage Change: 95.156250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `sample_selection` -- Executed in: 2.84s
# [rgb-logger - INFO]: `sample_selection` -- CPU User Time (Change): 9.60s
# [rgb-logger - INFO]: `sample_selection` -- CPU System Time: 6.36s
# [rgb-logger - INFO]: `sample_selection` -- CPU Total Time: 15.96s
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `sample_selection` -- Process-Specific CPU Usage (After): 562.00%
# [rgb-logger - INFO]: `sample_selection` -- Memory Usage Change: 95.156250 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `fore`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_fore`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.07s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.06s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.01s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.07s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 101.80%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.125000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Scan direction is: `aft`
# [rgb-logger - INFO]: `get_algorithm`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `get_algorithm` -- Started Execution
# [rgb-logger - INFO]: `get_algorithm` -- Executed in: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `get_algorithm` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `interp_variable_dict` -- Started Execution
# [rgb-logger - INFO]: Regridding: `bt_h_aft`
# [rgb-logger - INFO]: `interp_variable_dict` -- Executed in: 0.07s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU User Time (Change): 0.05s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU System Time: 0.02s
# [rgb-logger - INFO]: `interp_variable_dict` -- CPU Total Time: 0.07s
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Process-Specific CPU Usage (After): 100.00%
# [rgb-logger - INFO]: `interp_variable_dict` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds`
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: `create_output_grid_inds` -- Started Execution
# [rgb-logger - INFO]: `create_output_grid_inds` -- Executed in: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU User Time (Change): 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU System Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- CPU Total Time: 0.00s
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (Before): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Process-Specific CPU Usage (After): 0.00%
# [rgb-logger - INFO]: `create_output_grid_inds` -- Memory Usage Change: 0.000000 MB
# [rgb-logger - INFO]: ---------------------
# [rgb-logger - INFO]: Finished regridding band: `L`

# %%
# Plot the data on a 9km grid
fig, axs = plt.subplots(1, 3)
im1 = axs[0].imshow(output_data['5'][:,2800:3600], cmap = 'viridis')
axs[0].set_title('search_radius = 5km')
im2 = axs[1].imshow(output_data['10'][:,2800:3600], cmap = 'viridis')
axs[1].set_title('search_radius = 10km')
im3 = axs[2].imshow(output_data['30'][:,2800:3600], cmap = 'viridis')
axs[2].set_title('search_radius = 30')
colorbar = fig.colorbar(im1, ax=axs[0])
colorbar = fig.colorbar(im2, ax=axs[1])
colorbar = fig.colorbar(im3, ax=axs[2])
colorbar.set_label('BT [K]', fontsize=12)
plt.suptitle('Search Radius Comparison on EASE2 G9km')
plt.show()
# Out:
# {'5': array([[         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ..., 238.33769226,
#                  nan,          nan],
#        ...,
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan]], shape=(1624, 3856)), '10': array([[238.42680359, 238.45454407, 238.49917603, ..., 238.06008911,
#         238.06010437, 238.4140625 ],
#        [238.29966736, 238.23847961, 238.20671082, ..., 238.57771301,
#         238.48339844, 238.38569641],
#        [238.33769226, 238.337677  ,          nan, ..., 238.33769226,
#         238.33769226, 238.33770752],
#        ...,
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan]], shape=(1624, 3856)), '30': array([[238.68014526, 238.72872925, 238.77905273, ..., 238.64137268,
#         238.65036011, 238.66125488],
#        [238.31280518, 238.29708862, 238.30900574, ..., 238.41493225,
#         238.38827515, 238.3477478 ],
#        [238.3009491 , 238.42260742, 238.65376282, ..., 238.13829041,
#         238.13493347, 238.20573425],
#        ...,
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,          nan,          nan, ...,          nan,
#                  nan,          nan]], shape=(1624, 3856))}
