# %% [markdown]
# # JB3 - Algorithm Tuning for the basic algorithms
#
# This notebook will show you how to generate an output for the basic regridding algorithms and play around with the tuneable paramters for these algorithms, which are search_radius and max_neighbours. We will first show a comparison of the 3 different algorithms for the same tuning parameters and then we demonstrate how to play around with the tuning parameters.
